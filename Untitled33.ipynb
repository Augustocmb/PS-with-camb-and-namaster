# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
#making the cmap
cmap=cm.RdBu_r
#cmap.set_under(’w’) #set background to white
#cmapseismic=cm.seismic
#cmapseismic.set_under(’w’) #set background to white

# %%
import healpy as hp
# Out:
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).

# %%
planck_IQU_SMICA=hp.read_map('/home/augusto/Descargas/COM_CMB_IQU-smica_2048_R3.00_hm2.fits')
fig=plt.figure(1)
hp.mollview(planck_IQU_SMICA, min=-0.0003,max=0.0003,
title='Planck Temperature Map',fig=1,unit='K',cmap=cmap)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys, platform, os
import matplotlib
from matplotlib import pyplot as plt
import numpy as np

# %%
camb_path = os.path.realpath(os.path.join(os.getcwd(),'..'))
sys.path.insert(0,camb_path)
import camb
from camb import model, initialpower

# %%
#Set up a new set of parameters for CAMB
pars = camb.CAMBparams()

pars.set_cosmology(H0=70, ombh2=0.019, omch2=0.122, mnu=0.06, omk=0.05, tau=0.06)
pars.InitPower.set_params(As=2e-9, ns=0.965, r=0)
pars.set_for_lmax(2500, lens_potential_accuracy=0);

# %%
#calculate results for these parameters
results = camb.get_results(pars)

# %%
#get dictionary of CAMB power spectra
powers =results.get_cmb_power_spectra(pars, CMB_unit='muK')

# %%
#plot the total lensed CMB power spectra 
totCL=powers['total']
unlensedCL=powers['unlensed_scalar']
ls = np.arange(totCL.shape[0])
plt.figure(figsize=(12, 5))

plt.plot(ls, unlensedCL[:,0], '.', alpha = 0.5, label ='results for camb')
plt.xlabel(r'$\ell$')
plt.ylabel(r"$D_\ell~[\mu K^2]$")
plt.legend()
plt.grid()
plt.savefig('example1.png')

# %%
nside=64
cl=unlensedCL[:,0]*2*np.pi/[ls*(ls+1)]/(1e6)**2
map = hp.sphtfunc.synfast(cl,nside=nside, lmax=None)
# Out:
# /tmp/ipykernel_9649/443788911.py:2: RuntimeWarning: invalid value encountered in true_divide
#   cl=unlensedCL[:,0]*2*np.pi/[ls*(ls+1)]/(1e6)**2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9649/443788911.py in <module>
#       1 nside=64
#       2 cl=unlensedCL[:,0]*2*np.pi/[ls*(ls+1)]/(1e6)**2
# ----> 3 map = hp.sphtfunc.synfast(cl,nside=nside, lmax=None)
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     544                     warnings.warn(msg, warning_type, stacklevel=2)
#     545
# --> 546             return function(*args, **kwargs)
#     547
#     548         return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/healpy/sphtfunc.py in synfast(cls, nside, lmax, mmax, alm, pol, pixwin, fwhm, sigma, new, verbose)
#     568         lmax = min(cls_lmax, 3 * nside - 1)
#     569     alms = synalm(cls, lmax=lmax, mmax=mmax, new=new)
# --> 570     maps = alm2map(
#     571         alms,
#     572         nside,
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     544                     warnings.warn(msg, warning_type, stacklevel=2)
#     545
# --> 546             return function(*args, **kwargs)
#     547
#     548         return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/healpy/sphtfunc.py in alm2map(alms, nside, lmax, mmax, pixwin, fwhm, sigma, pol, inplace, verbose)
#     387         mmax = -1
#     388     if pol:
# --> 389         output = sphtlib._alm2map(
#     390             alms_new[0] if lonely else tuple(alms_new), nside, lmax=lmax, mmax=mmax
#     391         )
#
# TypeError: First argument must be a sequence with three elements.
